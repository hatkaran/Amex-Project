# %% [markdown]
# <a href="https://colab.research.google.com/github/hatkaran/Amex-Project/blob/main/Amex_Train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importing pandas

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Importing Data and converting csv to feather.

# %%
Train_Data = pd.read_csv(r"/content/drive/MyDrive/Req. Amex Docs/Amex_Campus_Challenge_Train - Copy.csv")

# %%
Train_Data
# Out:
#         ind_recommended  activation  customer_digital_activity_04  \
# 0                     0           0                           NaN
# 1                     0           0                           NaN
# 2                     0           1                           NaN
# 3                     0           0                           NaN
# 4                     1           0                           NaN
# ...                 ...         ...                           ...
# 137020                0           0                           NaN
# 137021                1           0                           NaN
# 137022                0           0                           NaN
# 137023                0           0                           4.0
# 137024                1           0                           NaN
#
#         customer_spend_01  customer_industry_spend_01  \
# 0              107.215862                   26.686594
# 1               35.552000                   50.928261
# ...

# %% [markdown]
# ### Info of each column

# %%
Train_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137025 entries, 0 to 137024
# Data columns (total 71 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   ind_recommended               137025 non-null  int64
#  1   activation                    137025 non-null  int64
#  2   customer_digital_activity_04  16362 non-null   float64
#  3   customer_spend_01             113861 non-null  float64
#  4   customer_industry_spend_01    71130 non-null   float64
#  5   customer_industry_spend_02    71130 non-null   float64
#  6   customer_industry_spend_03    71130 non-null   float64
#  7   customer_industry_spend_04    71130 non-null   float64
#  8   customer_industry_spend_05    71130 non-null   float64
#  9   customer_spend_02             113861 non-null  float64
#  10  customer_spend_03             126480 non-null  float64
#  11  customer_merchant_02          26 non-null      float64
# ...

# %% [markdown]
# ### Changing dtype of categorical feature form float64 to category

# %%
Train_Data[["merchant_profile_01"]] = Train_Data[["merchant_profile_01"]].astype("category")

# %%
Train_Data[["merchant_profile_01",]].dtypes
# Out:
# merchant_profile_01    category
# dtype: object

# %%
Train_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137025 entries, 0 to 137024
# Data columns (total 71 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   ind_recommended               137025 non-null  int64
#  1   activation                    137025 non-null  int64
#  2   customer_digital_activity_04  16362 non-null   float64
#  3   customer_spend_01             113861 non-null  float64
#  4   customer_industry_spend_01    71130 non-null   float64
#  5   customer_industry_spend_02    71130 non-null   float64
#  6   customer_industry_spend_03    71130 non-null   float64
#  7   customer_industry_spend_04    71130 non-null   float64
#  8   customer_industry_spend_05    71130 non-null   float64
#  9   customer_spend_02             113861 non-null  float64
#  10  customer_spend_03             126480 non-null  float64
#  11  customer_merchant_02          26 non-null      float64
# ...

# %% [markdown]
# ### Number of unique elements in each column

# %%
# Store the original display options
original_max_rows = pd.get_option('display.max_rows')
original_max_columns = pd.get_option('display.max_columns')

# Set display options to show all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Display the entire DataFrame
Train_Data.nunique()
# Out:
# ind_recommended                      2
# activation                           2
# customer_digital_activity_04       225
# customer_spend_01                92164
# customer_industry_spend_01       57322
# customer_industry_spend_02         207
# customer_industry_spend_03       53735
# customer_industry_spend_04         571
# customer_industry_spend_05         331
# customer_spend_02                   68
# customer_spend_03                  365
# customer_merchant_02                 3
# customer_merchant_01                26
# customer_spend_04                36448
# customer_spend_05               109014
# customer_spend_06                 1874
# customer_spend_07                  360
# merchant_spend_01                85870
# merchant_spend_02                 1314
# merchant_spend_03                23933
# merchant_spend_04                  491
# merchant_spend_05                  631
# merchant_spend_06                  101
# merchant_spend_07                80066
# ...

# %%
# Reset display options to their original values
pd.set_option('display.max_rows', original_max_rows)
pd.set_option('display.max_columns', original_max_columns)

# %% [markdown]
# ### Some operations on copy of Train_Data

# %%
train = pd.DataFrame(Train_Data)

# %%
train["total_customer_digital_activity"] = train[["customer_digital_activity_01","customer_digital_activity_02","customer_digital_activity_03","customer_digital_activity_04","customer_digital_activity_05","customer_digital_activity_06","customer_digital_activity_07","customer_digital_activity_08","customer_digital_activity_09","customer_digital_activity_10","customer_digital_activity_11","customer_digital_activity_12","customer_digital_activity_13","customer_digital_activity_14","customer_digital_activity_15","customer_digital_activity_16","customer_digital_activity_17","customer_digital_activity_18","customer_digital_activity_19","customer_digital_activity_20","customer_digital_activity_21","customer_digital_activity_22"]].sum(axis=1)

# %%
train["avg_distance"] = train[["distance_01","distance_02","distance_03","distance_04","distance_05"]].mean(axis=1)

# %%
train = train.drop(["customer_merchant_01","customer_merchant_02","customer_digital_activity_01","customer_digital_activity_02","customer_digital_activity_03","customer_digital_activity_04","customer_digital_activity_05","customer_digital_activity_06","customer_digital_activity_07","customer_digital_activity_08","customer_digital_activity_09","customer_digital_activity_10","customer_digital_activity_11","customer_digital_activity_12","customer_digital_activity_13","customer_digital_activity_14","customer_digital_activity_15","customer_digital_activity_16","customer_digital_activity_17","customer_digital_activity_18","customer_digital_activity_19","customer_digital_activity_20","customer_digital_activity_21","customer_digital_activity_22","distance_01","distance_02","distance_03","distance_04","distance_05"],axis=1)

# %%
train = train.drop(137024,axis=0)

# %%
train.shape
# Out:
# (137025, 44)

# %%
# Store the original display options
original_max_columns = pd.get_option('display.max_columns')

# Set display options to show all rows and columns
pd.set_option('display.max_columns', None)

train = train[["customer","merchant",'ind_recommended','activation',"customer_profile_01","customer_profile_02","customer_profile_03","customer_profile_04","merchant_profile_01","merchant_profile_02","merchant_profile_03","customer_merchant_03","avg_distance","total_customer_digital_activity","customer_spend_01","customer_spend_02","customer_spend_03","customer_spend_04","customer_spend_05","customer_spend_06","customer_spend_07","customer_spend_13","customer_spend_14","customer_spend_15","customer_spend_16","customer_spend_17","customer_spend_18","customer_spend_19","customer_industry_spend_01","customer_industry_spend_02","customer_industry_spend_03","customer_industry_spend_04","customer_industry_spend_05","merchant_spend_01","merchant_spend_02","merchant_spend_03","merchant_spend_04","merchant_spend_05","merchant_spend_06","merchant_spend_07","merchant_spend_08","merchant_spend_09","merchant_spend_10","merchant_spend_11"]]

# %%
train
# Out:
#         customer  merchant  ind_recommended  activation  customer_profile_01  \
# 0       168972.0  152285.0                0           0              5466.06
# 1       212404.0   39032.0                0           0               781.56
# 2       225178.0    7439.0                0           1              1457.84
# 3       183948.0  485069.0                0           0               351.22
# 4       210107.0  536004.0                1           0               831.67
# ...          ...       ...              ...         ...                  ...
# 137019  103144.0  134282.0                1           0              3799.12
# 137020  106693.0  312887.0                0           0               306.27
# 137021    7839.0  589342.0                1           0                57.15
# 137022  219099.0  226506.0                0           0               234.98
# 137023   65384.0  427066.0                0           0                31.08
#
# ...

# %%
pd.set_option('display.max_columns', original_max_columns)

# %%
train.columns
# Out:
# Index(['customer', 'merchant', 'ind_recommended', 'activation',
#        'customer_profile_01', 'customer_profile_02', 'customer_profile_03',
#        'customer_profile_04', 'merchant_profile_01', 'merchant_profile_02',
#        'merchant_profile_03', 'customer_merchant_03', 'avg_distance',
#        'total_customer_digital_activity', 'customer_spend_01',
#        'customer_spend_02', 'customer_spend_03', 'customer_spend_04',
#        'customer_spend_05', 'customer_spend_06', 'customer_spend_07',
#        'customer_spend_13', 'customer_spend_14', 'customer_spend_15',
#        'customer_spend_16', 'customer_spend_17', 'customer_spend_18',
#        'customer_spend_19', 'customer_industry_spend_01',
#        'customer_industry_spend_02', 'customer_industry_spend_03',
#        'customer_industry_spend_04', 'customer_industry_spend_05',
#        'merchant_spend_01', 'merchant_spend_02', 'merchant_spend_03',
#        'merchant_spend_04', 'merchant_spend_05', 'merchant_spend_06',
# ...

# %%
train.groupby(["customer","merchant"]).ngroups
# This means we have unique combinations of "customer" and "merchant"
# We have one null pair of "customer" and "merchant"
# Out:
# 137024

# %%
train.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Boxplots of every column to check data distribution

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

numeric_columns = train.select_dtypes(include=[np.number])
for column in numeric_columns:
    # Create a box plot using Seaborn
    sns.set(style="whitegrid")  # Set the style
    plt.figure(figsize=(8,6))  # Set the figure size
    sns.boxplot(y=train[column].values)
    plt.title(column)
    plt.show()

# %%
import pandas as pd
import numpy as np

# Define a function to replace outliers with column median using Z-score
def replace_outliers_with_median_zscore(df, z_thresh=3):

    for column in df.columns:
        non_null_mask = df[column].notnull()  # Create a boolean mask for non-null values

        column_median = df.loc[non_null_mask, column].median()  # Calculate median using non-null values
        column_std = df.loc[non_null_mask, column].std()  # Calculate standard deviation using non-null values

        z_scores = np.abs((df[column] - column_median) / column_std)
        df[column] = np.where(z_scores > z_thresh, np.where(non_null_mask, column_median, np.nan), df[column])

    return df

# Call the function to replace outliers with median
train[["merchant_spend_04","merchant_spend_05","merchant_spend_06","customer_industry_spend_04","customer_spend_01","customer_spend_02"]] = replace_outliers_with_median_zscore(train.loc[:,["merchant_spend_04","merchant_spend_05","merchant_spend_06","customer_industry_spend_04","customer_spend_01","customer_spend_02"]])

train
# Out:
#         customer  merchant  ind_recommended  activation  customer_profile_01  \
# 0       168972.0  152285.0                0           0              5466.06
# 1       212404.0   39032.0                0           0               781.56
# 2       225178.0    7439.0                0           1              1457.84
# 3       183948.0  485069.0                0           0               351.22
# 4       210107.0  536004.0                1           0               831.67
# ...          ...       ...              ...         ...                  ...
# 137019  103144.0  134282.0                1           0              3799.12
# 137020  106693.0  312887.0                0           0               306.27
# 137021    7839.0  589342.0                1           0                57.15
# 137022  219099.0  226506.0                0           0               234.98
# 137023   65384.0  427066.0                0           0                31.08
#
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

numeric_columns = train.select_dtypes(include=[np.number])
for column in numeric_columns:
    # Create a box plot using Seaborn
    sns.set(style="whitegrid")  # Set the style
    plt.figure(figsize=(8,6))  # Set the figure size
    sns.boxplot(y=train[column].values)
    plt.title(column)
    plt.show()

# %% [markdown]
# ### Null values in categorical feature are replaced by mode of respective columns

# %%
#filling null values of a categorical column through mode imputation
mode_value = train["merchant_profile_01"].mode().values[0]
imputed_values = train["merchant_profile_01"].fillna(mode_value)
train["merchant_profile_01"] = imputed_values

# %% [markdown]
# ### One hot encoding

# %%
# Perform one-hot encoding on the 'Specific Ailments' column
train = pd.get_dummies(train , columns=["merchant_profile_01"])

# Print the encoded data
train
# Out:
#         customer  merchant  ind_recommended  activation  customer_profile_01  \
# 0       168972.0  152285.0                0           0              5466.06
# 1       212404.0   39032.0                0           0               781.56
# 2       225178.0    7439.0                0           1              1457.84
# 3       183948.0  485069.0                0           0               351.22
# 4       210107.0  536004.0                1           0               831.67
# ...          ...       ...              ...         ...                  ...
# 137019  103144.0  134282.0                1           0              3799.12
# 137020  106693.0  312887.0                0           0               306.27
# 137021    7839.0  589342.0                1           0                57.15
# 137022  219099.0  226506.0                0           0               234.98
# 137023   65384.0  427066.0                0           0                31.08
#
# ...

# %%
print(train.columns.to_list())
# Out:
# ['customer', 'merchant', 'ind_recommended', 'activation', 'customer_profile_01', 'customer_profile_02', 'customer_profile_03', 'customer_profile_04', 'merchant_profile_02', 'merchant_profile_03', 'customer_merchant_03', 'avg_distance', 'total_customer_digital_activity', 'customer_spend_01', 'customer_spend_02', 'customer_spend_03', 'customer_spend_04', 'customer_spend_05', 'customer_spend_06', 'customer_spend_07', 'customer_spend_13', 'customer_spend_14', 'customer_spend_15', 'customer_spend_16', 'customer_spend_17', 'customer_spend_18', 'customer_spend_19', 'customer_industry_spend_01', 'customer_industry_spend_02', 'customer_industry_spend_03', 'customer_industry_spend_04', 'customer_industry_spend_05', 'merchant_spend_01', 'merchant_spend_02', 'merchant_spend_03', 'merchant_spend_04', 'merchant_spend_05', 'merchant_spend_06', 'merchant_spend_07', 'merchant_spend_08', 'merchant_spend_09', 'merchant_spend_10', 'merchant_spend_11', 'merchant_profile_01_101.0', 'merchant_profile_01_10
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137024 entries, 0 to 137023
# Columns: 110 entries, customer to merchant_profile_01_507.0
# dtypes: float64(41), int64(2), uint8(67)
# memory usage: 53.7 MB

# %% [markdown]
# ### No null values in any output column of one hot encoding done on merchant_profile_01

# %%
train[['merchant_profile_01_101.0', 'merchant_profile_01_102.0', 'merchant_profile_01_103.0', 'merchant_profile_01_201.0', 'merchant_profile_01_202.0', 'merchant_profile_01_203.0', 'merchant_profile_01_301.0', 'merchant_profile_01_302.0', 'merchant_profile_01_303.0', 'merchant_profile_01_304.0', 'merchant_profile_01_305.0', 'merchant_profile_01_306.0', 'merchant_profile_01_307.0', 'merchant_profile_01_308.0', 'merchant_profile_01_309.0', 'merchant_profile_01_311.0', 'merchant_profile_01_312.0', 'merchant_profile_01_313.0', 'merchant_profile_01_314.0', 'merchant_profile_01_315.0', 'merchant_profile_01_317.0', 'merchant_profile_01_319.0', 'merchant_profile_01_320.0', 'merchant_profile_01_321.0', 'merchant_profile_01_322.0', 'merchant_profile_01_324.0', 'merchant_profile_01_325.0', 'merchant_profile_01_326.0', 'merchant_profile_01_327.0', 'merchant_profile_01_328.0', 'merchant_profile_01_329.0', 'merchant_profile_01_330.0', 'merchant_profile_01_331.0', 'merchant_profile_01_332.0', 'merchant_profile_01_333.0', 'merchant_profile_01_335.0', 'merchant_profile_01_336.0', 'merchant_profile_01_337.0', 'merchant_profile_01_338.0', 'merchant_profile_01_339.0', 'merchant_profile_01_340.0', 'merchant_profile_01_342.0', 'merchant_profile_01_401.0', 'merchant_profile_01_402.0', 'merchant_profile_01_403.0', 'merchant_profile_01_405.0', 'merchant_profile_01_406.0', 'merchant_profile_01_407.0', 'merchant_profile_01_408.0', 'merchant_profile_01_409.0', 'merchant_profile_01_410.0', 'merchant_profile_01_411.0', 'merchant_profile_01_412.0', 'merchant_profile_01_413.0', 'merchant_profile_01_414.0', 'merchant_profile_01_415.0', 'merchant_profile_01_416.0', 'merchant_profile_01_417.0', 'merchant_profile_01_418.0', 'merchant_profile_01_419.0', 'merchant_profile_01_420.0', 'merchant_profile_01_501.0', 'merchant_profile_01_502.0', 'merchant_profile_01_503.0', 'merchant_profile_01_504.0', 'merchant_profile_01_506.0', 'merchant_profile_01_507.0']].isnull().sum()
# Out:
# merchant_profile_01_101.0    0
# merchant_profile_01_102.0    0
# merchant_profile_01_103.0    0
# merchant_profile_01_201.0    0
# merchant_profile_01_202.0    0
#                             ..
# merchant_profile_01_502.0    0
# merchant_profile_01_503.0    0
# merchant_profile_01_504.0    0
# merchant_profile_01_506.0    0
# merchant_profile_01_507.0    0
# Length: 67, dtype: int64

# %% [markdown]
# ### Null values illustrated using heatmap

# %%
sns.heatmap(train[['merchant_profile_01_101.0', 'merchant_profile_01_102.0', 'merchant_profile_01_103.0', 'merchant_profile_01_201.0', 'merchant_profile_01_202.0', 'merchant_profile_01_203.0', 'merchant_profile_01_301.0', 'merchant_profile_01_302.0', 'merchant_profile_01_303.0', 'merchant_profile_01_304.0', 'merchant_profile_01_305.0', 'merchant_profile_01_306.0', 'merchant_profile_01_307.0', 'merchant_profile_01_308.0', 'merchant_profile_01_309.0', 'merchant_profile_01_311.0', 'merchant_profile_01_312.0', 'merchant_profile_01_313.0', 'merchant_profile_01_314.0', 'merchant_profile_01_315.0', 'merchant_profile_01_317.0', 'merchant_profile_01_319.0', 'merchant_profile_01_320.0', 'merchant_profile_01_321.0', 'merchant_profile_01_322.0', 'merchant_profile_01_324.0', 'merchant_profile_01_325.0', 'merchant_profile_01_326.0', 'merchant_profile_01_327.0', 'merchant_profile_01_328.0', 'merchant_profile_01_329.0', 'merchant_profile_01_330.0', 'merchant_profile_01_331.0', 'merchant_profile_01_332.0', 'merchant_profile_01_333.0', 'merchant_profile_01_335.0', 'merchant_profile_01_336.0', 'merchant_profile_01_337.0', 'merchant_profile_01_338.0', 'merchant_profile_01_339.0', 'merchant_profile_01_340.0', 'merchant_profile_01_342.0', 'merchant_profile_01_401.0', 'merchant_profile_01_402.0', 'merchant_profile_01_403.0', 'merchant_profile_01_405.0', 'merchant_profile_01_406.0', 'merchant_profile_01_407.0', 'merchant_profile_01_408.0', 'merchant_profile_01_409.0', 'merchant_profile_01_410.0', 'merchant_profile_01_411.0', 'merchant_profile_01_412.0', 'merchant_profile_01_413.0', 'merchant_profile_01_414.0', 'merchant_profile_01_415.0', 'merchant_profile_01_416.0', 'merchant_profile_01_417.0', 'merchant_profile_01_418.0', 'merchant_profile_01_419.0', 'merchant_profile_01_420.0', 'merchant_profile_01_501.0', 'merchant_profile_01_502.0', 'merchant_profile_01_503.0', 'merchant_profile_01_504.0', 'merchant_profile_01_506.0', 'merchant_profile_01_507.0']].isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
sns.heatmap(train.drop(['merchant_profile_01_101.0', 'merchant_profile_01_102.0', 'merchant_profile_01_103.0', 'merchant_profile_01_201.0', 'merchant_profile_01_202.0', 'merchant_profile_01_203.0', 'merchant_profile_01_301.0', 'merchant_profile_01_302.0', 'merchant_profile_01_303.0', 'merchant_profile_01_304.0', 'merchant_profile_01_305.0', 'merchant_profile_01_306.0', 'merchant_profile_01_307.0', 'merchant_profile_01_308.0', 'merchant_profile_01_309.0', 'merchant_profile_01_311.0', 'merchant_profile_01_312.0', 'merchant_profile_01_313.0', 'merchant_profile_01_314.0', 'merchant_profile_01_315.0', 'merchant_profile_01_317.0', 'merchant_profile_01_319.0', 'merchant_profile_01_320.0', 'merchant_profile_01_321.0', 'merchant_profile_01_322.0', 'merchant_profile_01_324.0', 'merchant_profile_01_325.0', 'merchant_profile_01_326.0', 'merchant_profile_01_327.0', 'merchant_profile_01_328.0', 'merchant_profile_01_329.0', 'merchant_profile_01_330.0', 'merchant_profile_01_331.0', 'merchant_profile_01_332.0', 'merchant_profile_01_333.0', 'merchant_profile_01_335.0', 'merchant_profile_01_336.0', 'merchant_profile_01_337.0', 'merchant_profile_01_338.0', 'merchant_profile_01_339.0', 'merchant_profile_01_340.0', 'merchant_profile_01_342.0', 'merchant_profile_01_401.0', 'merchant_profile_01_402.0', 'merchant_profile_01_403.0', 'merchant_profile_01_405.0', 'merchant_profile_01_406.0', 'merchant_profile_01_407.0', 'merchant_profile_01_408.0', 'merchant_profile_01_409.0', 'merchant_profile_01_410.0', 'merchant_profile_01_411.0', 'merchant_profile_01_412.0', 'merchant_profile_01_413.0', 'merchant_profile_01_414.0', 'merchant_profile_01_415.0', 'merchant_profile_01_416.0', 'merchant_profile_01_417.0', 'merchant_profile_01_418.0', 'merchant_profile_01_419.0', 'merchant_profile_01_420.0', 'merchant_profile_01_501.0', 'merchant_profile_01_502.0', 'merchant_profile_01_503.0', 'merchant_profile_01_504.0', 'merchant_profile_01_506.0', 'merchant_profile_01_507.0'],axis=1).isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# ### KNN Imputation

# %%
import pandas as pd
import numpy as np
from sklearn.impute import KNNImputer

Columns = train.drop(["customer","merchant",'merchant_profile_01_101.0', 'merchant_profile_01_102.0', 'merchant_profile_01_103.0', 'merchant_profile_01_201.0', 'merchant_profile_01_202.0', 'merchant_profile_01_203.0', 'merchant_profile_01_301.0', 'merchant_profile_01_302.0', 'merchant_profile_01_303.0', 'merchant_profile_01_304.0', 'merchant_profile_01_305.0', 'merchant_profile_01_306.0', 'merchant_profile_01_307.0', 'merchant_profile_01_308.0', 'merchant_profile_01_309.0', 'merchant_profile_01_311.0', 'merchant_profile_01_312.0', 'merchant_profile_01_313.0', 'merchant_profile_01_314.0', 'merchant_profile_01_315.0', 'merchant_profile_01_317.0', 'merchant_profile_01_319.0', 'merchant_profile_01_320.0', 'merchant_profile_01_321.0', 'merchant_profile_01_322.0', 'merchant_profile_01_324.0', 'merchant_profile_01_325.0', 'merchant_profile_01_326.0', 'merchant_profile_01_327.0', 'merchant_profile_01_328.0', 'merchant_profile_01_329.0', 'merchant_profile_01_330.0', 'merchant_profile_01_331.0', 'merchant_profile_01_332.0', 'merchant_profile_01_333.0', 'merchant_profile_01_335.0', 'merchant_profile_01_336.0', 'merchant_profile_01_337.0', 'merchant_profile_01_338.0', 'merchant_profile_01_339.0', 'merchant_profile_01_340.0', 'merchant_profile_01_342.0', 'merchant_profile_01_401.0', 'merchant_profile_01_402.0', 'merchant_profile_01_403.0', 'merchant_profile_01_405.0', 'merchant_profile_01_406.0', 'merchant_profile_01_407.0', 'merchant_profile_01_408.0', 'merchant_profile_01_409.0', 'merchant_profile_01_410.0', 'merchant_profile_01_411.0', 'merchant_profile_01_412.0', 'merchant_profile_01_413.0', 'merchant_profile_01_414.0', 'merchant_profile_01_415.0', 'merchant_profile_01_416.0', 'merchant_profile_01_417.0', 'merchant_profile_01_418.0', 'merchant_profile_01_419.0', 'merchant_profile_01_420.0', 'merchant_profile_01_501.0', 'merchant_profile_01_502.0', 'merchant_profile_01_503.0', 'merchant_profile_01_504.0', 'merchant_profile_01_506.0', 'merchant_profile_01_507.0'],axis=1).columns

# Perform KNN imputation for selected columns
imputer = KNNImputer(n_neighbors=5)

# Impute in place
train[Columns] = imputer.fit_transform(train[Columns])
train[Columns] = train[Columns].astype(np.float32)

# %%
# Store the original display options
original_max_rows = pd.get_option('display.max_rows')

# Set display options to show all rows and columns
pd.set_option('display.max_rows', None)


train.isna().sum()
# Out:
# customer                           0
# merchant                           0
# ind_recommended                    0
# activation                         0
# customer_profile_01                0
# customer_profile_02                0
# customer_profile_03                0
# customer_profile_04                0
# merchant_profile_02                0
# merchant_profile_03                0
# customer_merchant_03               0
# avg_distance                       0
# total_customer_digital_activity    0
# customer_spend_01                  0
# customer_spend_02                  0
# customer_spend_03                  0
# customer_spend_04                  0
# customer_spend_05                  0
# customer_spend_06                  0
# customer_spend_07                  0
# customer_spend_13                  0
# customer_spend_14                  0
# customer_spend_15                  0
# customer_spend_16                  0
# customer_spend_17                  0
# ...

# %%
pd.set_option('display.max_rows', original_max_rows)

# %%
train.to_csv("/content/train.csv", index=False)

# %%
from IPython.display import HTML

HTML('<a href="/content/train.csv" download>Click here to download train.csv</a>')
# Out:
# <a href="/content/train.csv" download>Click here to download train.csv</a>

# %%
import shutil

# Move the CSV file to your Google Drive folder
source_file_path = "/content/train.csv"  # Path to your CSV file in Colab
target_folder_path = "/content/drive/MyDrive/Req. Amex Docs"  # Path to your Google Drive folder

shutil.move(source_file_path, target_folder_path)
# Out:
# '/content/drive/MyDrive/Req. Amex Docs/train.csv'

# %% [markdown]
# ### ---------------------------------------------------------------------------------------------------------------
